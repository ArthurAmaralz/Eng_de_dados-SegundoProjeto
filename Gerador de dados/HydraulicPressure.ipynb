# %%
# !pip install boto3

# %%
import boto3
import json
import random
import time
from datetime import datetime

### conectando ao kinesis ###
cliente = boto3.client('kinesis',aws_access_key_id = 'AKIA4EV3WDJO3WXT3TA4', # Alterar para sua key_id
                       aws_secret_access_key = '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', # Alterar para sua Access_key
                       region_name = 'us-east-1')

### Gerando dados para Power Factor ###

id=0

while True:
    if id < 500:
      id +=1
      dados = round(random.uniform(70, 80),2)  
      registro = {'id' : str(id), 'data' : str(dados), 'type' : "hydraulicpressure", 'timestamp' : str(datetime.now())}
    else:
      break 
   
    # Salvando os registros no kinesis
    cliente.put_record(              
    StreamName = 'arthurwindfarm',
    Data = json.dumps(registro),     #convertendo dados para o formato json
    PartitionKey = '02')             # chave de partição que gerará um hash. Se outro produtor tiver a mesma chave gerará o memso hash e irá pro mesmo shard no kinesis
    
    time.sleep(0.5)
    # print (registro)
# Out:
# {'id': '1', 'data': '71.67', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:26.685818'}
# {'id': '2', 'data': '70.91', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:27.187761'}
# {'id': '3', 'data': '71.17', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:27.689692'}
# {'id': '4', 'data': '76.82', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:28.191926'}
# {'id': '5', 'data': '79.39', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:28.692742'}
# {'id': '6', 'data': '76.02', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:29.193557'}
# {'id': '7', 'data': '77.52', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:29.694548'}
# {'id': '8', 'data': '70.94', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:30.195366'}
# {'id': '9', 'data': '71.9', 'type': 'hydraulicpressure', 'timestamp': '2022-10-19 17:53:30.696276'}
# ...
